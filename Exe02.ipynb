# %%
import pandas as pd

# %%
# consultar carpeta interna
df = pd.read_csv('./files/bill_auth.csv')

# %%
# consultar carpeta externa
pd.read_csv("D:/Documents/UNI/MD-Mineria_Datos/archivos/bill_auth.csv")
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
#ver los primeros registros
df.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
# ver los ultimos registros
df.tail()
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1

# %%
df2 = pd.read_csv('./files/bill_auth.csv', sep=',')

# %%
df2 = pd.read_csv('./files/bill_auth.csv', header=None)

# %%
df2 = pd.read_csv('./files/bill_auth.csv', names=['a','b','c','d','message'], skiprows = [0])

# %%
names = ['a','b','c','d','message']

# %%
df2 = pd.read_csv('./files/bill_auth.csv', names = names, index_col = 'message')

# %%
df2 = pd.read_csv('./files/bill_auth.csv', nrows = 2)

# %%
df2
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0    3.6216    8.6661   -2.8073 -0.44699      0
# 1    4.5459    8.1674   -2.4586 -1.46210      0

# %%
df.to_json('./files/bill_auth.json')

# %%
df_js = pd.read_json('./files/bill_auth.json')

# %%
df_js
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]
